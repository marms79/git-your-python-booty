# %% [markdown]
# # Reading and writing data
#
# Here we'll go over some of the most common ways of handling data, including:
# 1. Standard out
# 2. Reading data from a file
# 3. Writing data to a file
# 4. Getting user input
# 5. Pandas

# %% [markdown]
# ## 1. Standard out
#
# "Standard out" (stdout) is simply where a program prints/writes its output data by default. For example, when you open your interactive Python shell and type
#     >>> 3 + 2
# the ```5``` that shows up is what was written to stdout.

# %%
5 + 6  # the 11 that gets shown in the output is your stdout

# %% [markdown]
# Cool. But what about reading data from files? Or writing to them?

# %% [markdown]
# ## 2. Reading data from a file
#
# The file "sample_data_50.csv" contains the following headers:
# id, first_name, country, age, gender
#
# The first few rows look like this:
# ```
#     id,first_name,country,age,gender
#     1,Nicholas,Honduras,43,M
#     2,Mildred,Indonesia,31,F
#     3,Catherine,Malaysia,33,F
# ```
# Columns are delineated by commas, so the data is said to be in comma-separated value or "csv" format. The data in this sample file is 50 lines of random data generated by http://www.mockaroo.com/.

# %% [markdown]
# ### Basic Way to Open and Read a File

# %%
sample_filename = './sample_data_50.csv'

file_object = open(sample_filename, 'rb')  # create a file object using the open() method and set the 
                                           # access mode to "read in binary mode"
    
for line in file_object:  # loop over the file object to read each line:
    print line
    
file_object.close()  # IMPORTANT!!!

# %% [markdown]
# ### Note!!!
# This is NOT the recommended way to read a file because the user has to remember to close the file when they're finished with it. All files are *supposed* to be closed upon termination of a script, but sometimes this doesn't happen. If your file is big enough, this can cause some gnarly problems.

# %% [markdown]
# ### The Pythonic Way
#
# Use the **with** statement. There's a lot going on behind the scenes of **with**, but all you really need to know to use it is that it handles file opening and closing for you.
#
# No matter what happens after you open the file (say, your program crashes because of an error), **with** makes sure that the file is closed properly. That is, 99.999% of the time. ;)

# %%
sample_filename = './sample_data_50.csv'

with open(sample_filename, 'rb') as file_object:
    for line in file_object:
        print line

# %% [markdown]
# ### Using the csv Module
# The csv module provides a way to read in distinct values for each row and column of a csv file.  You can define things like delimiters and quote characters, and read in data from different sources, including Excel.  In the next cell we will use the csv module to read in values from a csv file.

# %%
import csv
sample_filename = './sample_data_50.csv'

with open(sample_filename, 'rb') as csvfile:
    # Return an object that will iterate over each line in the file.
    reader = csv.reader(csvfile, delimiter=',')   
    
    # next will read one line.  Once a line is read it cannot read again
    headers = next(reader)
    print headers
    for row in reader:  # read lines sequentially
        row_id, first_name, country, age, gender = row
        print row

# %% [markdown]
# ### Exercise 1: add the rows to a list

# %%
import csv
sample_filename = './sample_data_50.csv'
data = []

with open(sample_filename, 'rb') as csvfile:
    # Return an object that will iterate over each line in the file.
    reader = csv.reader(csvfile, delimiter=',')   
    
    # next will read one line.  Once a line is read it cannot read again
    headers = next(reader)                        
    for row in reader:  # read lines sequentially
        row_id, first_name, country, age, gender = row
        data.append(row)
        
    print data
# Out:
# [['1', 'Nicholas', 'Honduras', '43', 'M'], ['2', 'Mildred', 'Indonesia', '31', 'F'], ['3', 'Catherine', 'Malaysia', '33', 'F'], ['4', 'Juan', 'China', '21', 'M'], ['5', 'Christopher', 'Indonesia', '73', 'M'], ['6', 'Bruce', 'Czech Republic', '34', 'M'], ['7', 'Patricia', 'Indonesia', '45', 'F'], ['8', 'Barbara', 'Philippines', '68', 'F'], ['9', 'Sandra', 'Belarus', '58', 'F'], ['10', 'Katherine', 'Thailand', '54', 'F'], ['11', 'Howard', 'Philippines', '76', 'M'], ['12', 'Chris', 'China', '43', 'M'], ['13', 'John', 'Philippines', '30', 'M'], ['14', 'Laura', 'Poland', '54', 'F'], ['15', 'Debra', 'France', '30', 'F'], ['16', 'Christina', 'Thailand', '55', 'F'], ['17', 'Gloria', 'France', '29', 'F'], ['18', 'Maria', 'Madagascar', '48', 'F'], ['19', 'Scott', 'Philippines', '24', 'M'], ['20', 'Paula', 'Thailand', '72', 'F'], ['21', 'Christopher', 'Tajikistan', '37', 'M'], ['22', 'Ryan', 'Peru', '73', 'M'], ['23', 'Anne', 'Ukraine', '76', 'F'], ['24', 'Charles', 'South Africa', '23', 'M'], ['25', 'Emily', 'China', '44', 'F'], ['26', 'Deborah', 'China', '37', 'F'], ['27', 'Jack', 'Yemen', '78', 'M'], ['28', 'Matthew', 'China', '38', 'M'], ['29', 'Janice', 'Brazil', '21', 'F'], ['30', 'Maria', 'Philippines', '52', 'F'], ['31', 'Justin', 'Philippines', '78', 'M'], ['32', 'Ryan', 'United States', '38', 'M'], ['33', 'David', 'Poland', '30', 'M'], ['34', 'Margaret', 'Albania', '72', 'F'], ['35', 'Kenneth', 'Indonesia', '70', 'M'], ['36', 'Ashley', 'France', '25', 'F'], ['37', 'Judy', 'China', '25', 'F'], ['38', 'Sarah', 'Bulgaria', '34', 'F'], ['39', 'Sarah', 'Greece', '66', 'F'], ['40', 'Susan', 'China', '32', 'F'], ['41', 'Gregory', 'France', '25', 'M'], ['42', 'Alice', 'Mexico', '60', 'F'], ['43', 'Jessica', 'Honduras', '64', 'F'], ['44', 'Jason', 'Ukraine', '30', 'M'], ['45', 'Susan', 'United States', '61', 'F'], ['46', 'Sarah', 'Brazil', '20', 'F'], ['47', 'Helen', 'Czech Republic', '47', 'F'], ['48', 'Ryan', 'China', '54', 'M'], ['49', 'Maria', 'Pakistan', '72', 'F']]

# %% [markdown]
# ### Exercise 2: Add the rows to a dictionary

# %%
import csv
sample_filename = './sample_data_50.csv'
data = {}

with open(sample_filename, 'rb') as csvfile:
    # Return an object that will iterate over each line in the file.
    reader = csv.reader(csvfile, delimiter=',')   
    
    # next will read one line.  Once a line is read it cannot read again
    headers = next(reader)
    print headers
    for row in reader:  # read lines sequentially
        row_id, first_name, country, age, gender = row
        data[row_id] = {                 ###### this will only work if the row_id is unique
            'name' : first_name,
            'country' : country,
            'age' : age,
            'gender' : gender
        }
        
    print data.keys()
    
    for key in data.keys():
        print key, data[key]
# Out:
# ['id', 'first_name', 'country', 'age', 'gender']
# ['42', '48', '43', '49', '24', '25', '26', '27', '20', '21', '22', '23', '46', '47', '44', '45', '28', '29', '40', '41', '1', '3', '2', '5', '4', '7', '6', '9', '8', '39', '38', '11', '10', '13', '12', '15', '14', '17', '16', '19', '18', '31', '30', '37', '36', '35', '34', '33', '32']
# 42 {'country': 'Mexico', 'age': '60', 'name': 'Alice', 'gender': 'F'}
# 48 {'country': 'China', 'age': '54', 'name': 'Ryan', 'gender': 'M'}
# 43 {'country': 'Honduras', 'age': '64', 'name': 'Jessica', 'gender': 'F'}
# 49 {'country': 'Pakistan', 'age': '72', 'name': 'Maria', 'gender': 'F'}
# 24 {'country': 'South Africa', 'age': '23', 'name': 'Charles', 'gender': 'M'}
# 25 {'country': 'China', 'age': '44', 'name': 'Emily', 'gender': 'F'}
# 26 {'country': 'China', 'age': '37', 'name': 'Deborah', 'gender': 'F'}
# 27 {'country': 'Yemen', 'age': '78', 'name': 'Jack', 'gender': 'M'}
# 20 {'country': 'Thailand', 'age': '72', 'name': 'Paula', 'gender': 'F'}
# 21 {'country': 'Tajikistan', 'age': '37', 'name': 'Christopher', 'gender': 'M'}
# 22 {'country': 'Peru', 'age': '73', 'name': 'Ryan', 'gender': 'M'}
# 23 {'country': 'Ukraine', 'age': '76', 'name': 'Anne', 'gender': 'F'}
# 46 {'country': 'Brazil', 'age': '20', 'name': 'Sarah', 'gender': 'F'}
# 47 {'country': 'Czech Republic', 'age': '47', 'name': 'Helen', 'gender': 'F'}
# 44 {'country': 'Ukraine', 'age': '30', 'name': 'Jason', 'gender': 'M'}
# 45 {'country': 'United States', 'age': '61', 'name': 'Susan', 'gender': 'F'}
# 28 {'country': 'China', 'age': '38', 'name': 'Matthew', 'gender': 'M'}
# 29 {'country': 'Brazil', 'age': '21', 'name': 'Janice', 'gender': 'F'}
# 40 {'country': 'China', 'age': '32', 'name': 'Susan', 'gender': 'F'}
# 41 {'country': 'France', 'age': '25', 'name': 'Gregory', 'gender': 'M'}
# 1 {'country': 'Honduras', 'age': '43', 'name': 'Nicholas', 'gender': 'M'}
# 3 {'country': 'Malaysia', 'age': '33', 'name': 'Catherine', 'gender': 'F'}
# 2 {'country': 'Indonesia', 'age': '31', 'name': 'Mildred', 'gender': 'F'}
# 5 {'country': 'Indonesia', 'age': '73', 'name': 'Christopher', 'gender': 'M'}
# 4 {'country': 'China', 'age': '21', 'name': 'Juan', 'gender': 'M'}
# 7 {'country': 'Indonesia', 'age': '45', 'name': 'Patricia', 'gender': 'F'}
# 6 {'country': 'Czech Republic', 'age': '34', 'name': 'Bruce', 'gender': 'M'}
# 9 {'country': 'Belarus', 'age': '58', 'name': 'Sandra', 'gender': 'F'}
# 8 {'country': 'Philippines', 'age': '68', 'name': 'Barbara', 'gender': 'F'}
# 39 {'country': 'Greece', 'age': '66', 'name': 'Sarah', 'gender': 'F'}
# 38 {'country': 'Bulgaria', 'age': '34', 'name': 'Sarah', 'gender': 'F'}
# 11 {'country': 'Philippines', 'age': '76', 'name': 'Howard', 'gender': 'M'}
# 10 {'country': 'Thailand', 'age': '54', 'name': 'Katherine', 'gender': 'F'}
# 13 {'country': 'Philippines', 'age': '30', 'name': 'John', 'gender': 'M'}
# 12 {'country': 'China', 'age': '43', 'name': 'Chris', 'gender': 'M'}
# 15 {'country': 'France', 'age': '30', 'name': 'Debra', 'gender': 'F'}
# 14 {'country': 'Poland', 'age': '54', 'name': 'Laura', 'gender': 'F'}
# 17 {'country': 'France', 'age': '29', 'name': 'Gloria', 'gender': 'F'}
# 16 {'country': 'Thailand', 'age': '55', 'name': 'Christina', 'gender': 'F'}
# 19 {'country': 'Philippines', 'age': '24', 'name': 'Scott', 'gender': 'M'}
# 18 {'country': 'Madagascar', 'age': '48', 'name': 'Maria', 'gender': 'F'}
# 31 {'country': 'Philippines', 'age': '78', 'name': 'Justin', 'gender': 'M'}
# 30 {'country': 'Philippines', 'age': '52', 'name': 'Maria', 'gender': 'F'}
# 37 {'country': 'China', 'age': '25', 'name': 'Judy', 'gender': 'F'}
# 36 {'country': 'France', 'age': '25', 'name': 'Ashley', 'gender': 'F'}
# 35 {'country': 'Indonesia', 'age': '70', 'name': 'Kenneth', 'gender': 'M'}
# 34 {'country': 'Albania', 'age': '72', 'name': 'Margaret', 'gender': 'F'}
# 33 {'country': 'Poland', 'age': '30', 'name': 'David', 'gender': 'M'}
# 32 {'country': 'United States', 'age': '38', 'name': 'Ryan', 'gender': 'M'}

# %% [markdown]
# ## 3. Writing data to a file
#
# Next, let's try writing some data to a file.
#
# ### Basic way to open and write to a file

# %%
output_filename = './test_output.csv'
sample = ('the_answer', 42)  # a tuple
s = str(sample)  # convert the tuple to a string

# The 'w' indicates we are opening a file that we will write stuff to
output_file = open(output_filename, 'w')   
output_file.write(s)
output_file.close()

# %% [markdown]
# Again, this is **not** the recommended way of writing to a file. Reasons for this include:
# + the user must remember to convert all data to be written into a string
# + the user must remember to close the file afterwards

# %% [markdown]
# ### The Pythonic Way Using the csv Module

# %%
output_filename = './test_output.csv'

header = ['col0', 'col1', 'col2']

start_num = 1000
count = 0
with open(output_filename, 'w') as outcsvfile:
    mywriter = csv.writer(outcsvfile, delimiter=',')
    mywriter.writerow(header)
    
    while start_num >= 0:
        mywriter.writerow([start_num, count])
        start_num -= 1
        count += 1

# %%
input_file = './test_output.csv'

with open(input_file, 'rb') as csvfile:
    reader = csv.reader(csvfile, delimiter=',') 
    for row in reader:
        print row
# Out:
# ['col0', 'col1']
# ['1000', '0']
# ['999', '1']
# ['998', '2']
# ['997', '3']
# ['996', '4']
# ['995', '5']
# ['994', '6']
# ['993', '7']
# ['992', '8']
# ['991', '9']
# ['990', '10']
# ['989', '11']
# ['988', '12']
# ['987', '13']
# ['986', '14']
# ['985', '15']
# ['984', '16']
# ['983', '17']
# ['982', '18']
# ['981', '19']
# ['980', '20']
# ['979', '21']
# ['978', '22']
# ['977', '23']
# ['976', '24']
# ['975', '25']
# ['974', '26']
# ['973', '27']
# ['972', '28']
# ['971', '29']
# ['970', '30']
# ['969', '31']
# ['968', '32']
# ['967', '33']
# ['966', '34']
# ['965', '35']
# ['964', '36']
# ['963', '37']
# ['962', '38']
# ['961', '39']
# ['960', '40']
# ['959', '41']
# ['958', '42']
# ['957', '43']
# ['956', '44']
# ['955', '45']
# ['954', '46']
# ['953', '47']
# ['952', '48']
# ['951', '49']
# ['950', '50']
# ['949', '51']
# ['948', '52']
# ['947', '53']
# ['946', '54']
# ['945', '55']
# ['944', '56']
# ['943', '57']
# ['942', '58']
# ['941', '59']
# ['940', '60']
# ['939', '61']
# ['938', '62']
# ['937', '63']
# ['936', '64']
# ['935', '65']
# ['934', '66']
# ['933', '67']
# ['932', '68']
# ['931', '69']
# ['930', '70']
# ['929', '71']
# ['928', '72']
# ['927', '73']
# ['926', '74']
# ['925', '75']
# ['924', '76']
# ['923', '77']
# ['922', '78']
# ['921', '79']
# ['920', '80']
# ['919', '81']
# ['918', '82']
# ['917', '83']
# ['916', '84']
# ['915', '85']
# ['914', '86']
# ['913', '87']
# ['912', '88']
# ['911', '89']
# ['910', '90']
# ['909', '91']
# ['908', '92']
# ['907', '93']
# ['906', '94']
# ['905', '95']
# ['904', '96']
# ['903', '97']
# ['902', '98']
# ['901', '99']
# ['900', '100']
# ['899', '101']
# ['898', '102']
# ['897', '103']
# ['896', '104']
# ['895', '105']
# ['894', '106']
# ['893', '107']
# ['892', '108']
# ['891', '109']
# ['890', '110']
# ['889', '111']
# ['888', '112']
# ['887', '113']
# ['886', '114']
# ['885', '115']
# ['884', '116']
# ['883', '117']
# ['882', '118']
# ['881', '119']
# ['880', '120']
# ['879', '121']
# ['878', '122']
# ['877', '123']
# ['876', '124']
# ['875', '125']
# ['874', '126']
# ['873', '127']
# ['872', '128']
# ['871', '129']
# ['870', '130']
# ['869', '131']
# ['868', '132']
# ['867', '133']
# ['866', '134']
# ['865', '135']
# ['864', '136']
# ['863', '137']
# ['862', '138']
# ['861', '139']
# ['860', '140']
# ['859', '141']
# ['858', '142']
# ['857', '143']
# ['856', '144']
# ['855', '145']
# ['854', '146']
# ['853', '147']
# ['852', '148']
# ['851', '149']
# ['850', '150']
# ['849', '151']
# ['848', '152']
# ['847', '153']
# ['846', '154']
# ['845', '155']
# ['844', '156']
# ['843', '157']
# ['842', '158']
# ['841', '159']
# ['840', '160']
# ['839', '161']
# ['838', '162']
# ['837', '163']
# ['836', '164']
# ['835', '165']
# ['834', '166']
# ['833', '167']
# ['832', '168']
# ['831', '169']
# ['830', '170']
# ['829', '171']
# ['828', '172']
# ['827', '173']
# ['826', '174']
# ['825', '175']
# ['824', '176']
# ['823', '177']
# ['822', '178']
# ['821', '179']
# ['820', '180']
# ['819', '181']
# ['818', '182']
# ['817', '183']
# ['816', '184']
# ['815', '185']
# ['814', '186']
# ['813', '187']
# ['812', '188']
# ['811', '189']
# ['810', '190']
# ['809', '191']
# ['808', '192']
# ['807', '193']
# ['806', '194']
# ['805', '195']
# ['804', '196']
# ['803', '197']
# ['802', '198']
# ['801', '199']
# ['800', '200']
# ['799', '201']
# ['798', '202']
# ['797', '203']
# ['796', '204']
# ['795', '205']
# ['794', '206']
# ['793', '207']
# ['792', '208']
# ['791', '209']
# ['790', '210']
# ['789', '211']
# ['788', '212']
# ['787', '213']
# ['786', '214']
# ['785', '215']
# ['784', '216']
# ['783', '217']
# ['782', '218']
# ['781', '219']
# ['780', '220']
# ['779', '221']
# ['778', '222']
# ['777', '223']
# ['776', '224']
# ['775', '225']
# ['774', '226']
# ['773', '227']
# ['772', '228']
# ['771', '229']
# ['770', '230']
# ['769', '231']
# ['768', '232']
# ['767', '233']
# ['766', '234']
# ['765', '235']
# ['764', '236']
# ['763', '237']
# ['762', '238']
# ['761', '239']
# ['760', '240']
# ['759', '241']
# ['758', '242']
# ['757', '243']
# ['756', '244']
# ['755', '245']
# ['754', '246']
# ['753', '247']
# ['752', '248']
# ['751', '249']
# ['750', '250']
# ['749', '251']
# ['748', '252']
# ['747', '253']
# ['746', '254']
# ['745', '255']
# ['744', '256']
# ['743', '257']
# ['742', '258']
# ['741', '259']
# ['740', '260']
# ['739', '261']
# ['738', '262']
# ['737', '263']
# ['736', '264']
# ['735', '265']
# ['734', '266']
# ['733', '267']
# ['732', '268']
# ['731', '269']
# ['730', '270']
# ['729', '271']
# ['728', '272']
# ['727', '273']
# ['726', '274']
# ['725', '275']
# ['724', '276']
# ['723', '277']
# ['722', '278']
# ['721', '279']
# ['720', '280']
# ['719', '281']
# ['718', '282']
# ['717', '283']
# ['716', '284']
# ['715', '285']
# ['714', '286']
# ['713', '287']
# ['712', '288']
# ['711', '289']
# ['710', '290']
# ['709', '291']
# ['708', '292']
# ['707', '293']
# ['706', '294']
# ['705', '295']
# ['704', '296']
# ['703', '297']
# ['702', '298']
# ['701', '299']
# ['700', '300']
# ['699', '301']
# ['698', '302']
# ['697', '303']
# ['696', '304']
# ['695', '305']
# ['694', '306']
# ['693', '307']
# ['692', '308']
# ['691', '309']
# ['690', '310']
# ['689', '311']
# ['688', '312']
# ['687', '313']
# ['686', '314']
# ['685', '315']
# ['684', '316']
# ['683', '317']
# ['682', '318']
# ['681', '319']
# ['680', '320']
# ['679', '321']
# ['678', '322']
# ['677', '323']
# ['676', '324']
# ['675', '325']
# ['674', '326']
# ['673', '327']
# ['672', '328']
# ['671', '329']
# ['670', '330']
# ['669', '331']
# ['668', '332']
# ['667', '333']
# ['666', '334']
# ['665', '335']
# ['664', '336']
# ['663', '337']
# ['662', '338']
# ['661', '339']
# ['660', '340']
# ['659', '341']
# ['658', '342']
# ['657', '343']
# ['656', '344']
# ['655', '345']
# ['654', '346']
# ['653', '347']
# ['652', '348']
# ['651', '349']
# ['650', '350']
# ['649', '351']
# ['648', '352']
# ['647', '353']
# ['646', '354']
# ['645', '355']
# ['644', '356']
# ['643', '357']
# ['642', '358']
# ['641', '359']
# ['640', '360']
# ['639', '361']
# ['638', '362']
# ['637', '363']
# ['636', '364']
# ['635', '365']
# ['634', '366']
# ['633', '367']
# ['632', '368']
# ['631', '369']
# ['630', '370']
# ['629', '371']
# ['628', '372']
# ['627', '373']
# ['626', '374']
# ['625', '375']
# ['624', '376']
# ['623', '377']
# ['622', '378']
# ['621', '379']
# ['620', '380']
# ['619', '381']
# ['618', '382']
# ['617', '383']
# ['616', '384']
# ['615', '385']
# ['614', '386']
# ['613', '387']
# ['612', '388']
# ['611', '389']
# ['610', '390']
# ['609', '391']
# ['608', '392']
# ['607', '393']
# ['606', '394']
# ['605', '395']
# ['604', '396']
# ['603', '397']
# ['602', '398']
# ['601', '399']
# ['600', '400']
# ['599', '401']
# ['598', '402']
# ['597', '403']
# ['596', '404']
# ['595', '405']
# ['594', '406']
# ['593', '407']
# ['592', '408']
# ['591', '409']
# ['590', '410']
# ['589', '411']
# ['588', '412']
# ['587', '413']
# ['586', '414']
# ['585', '415']
# ['584', '416']
# ['583', '417']
# ['582', '418']
# ['581', '419']
# ['580', '420']
# ['579', '421']
# ['578', '422']
# ['577', '423']
# ['576', '424']
# ['575', '425']
# ['574', '426']
# ['573', '427']
# ['572', '428']
# ['571', '429']
# ['570', '430']
# ['569', '431']
# ['568', '432']
# ['567', '433']
# ['566', '434']
# ['565', '435']
# ['564', '436']
# ['563', '437']
# ['562', '438']
# ['561', '439']
# ['560', '440']
# ['559', '441']
# ['558', '442']
# ['557', '443']
# ['556', '444']
# ['555', '445']
# ['554', '446']
# ['553', '447']
# ['552', '448']
# ['551', '449']
# ['550', '450']
# ['549', '451']
# ['548', '452']
# ['547', '453']
# ['546', '454']
# ['545', '455']
# ['544', '456']
# ['543', '457']
# ['542', '458']
# ['541', '459']
# ['540', '460']
# ['539', '461']
# ['538', '462']
# ['537', '463']
# ['536', '464']
# ['535', '465']
# ['534', '466']
# ['533', '467']
# ['532', '468']
# ['531', '469']
# ['530', '470']
# ['529', '471']
# ['528', '472']
# ['527', '473']
# ['526', '474']
# ['525', '475']
# ['524', '476']
# ['523', '477']
# ['522', '478']
# ['521', '479']
# ['520', '480']
# ['519', '481']
# ['518', '482']
# ['517', '483']
# ['516', '484']
# ['515', '485']
# ['514', '486']
# ['513', '487']
# ['512', '488']
# ['511', '489']
# ['510', '490']
# ['509', '491']
# ['508', '492']
# ['507', '493']
# ['506', '494']
# ['505', '495']
# ['504', '496']
# ['503', '497']
# ['502', '498']
# ['501', '499']
# ['500', '500']
# ['499', '501']
# ['498', '502']
# ['497', '503']
# ['496', '504']
# ['495', '505']
# ['494', '506']
# ['493', '507']
# ['492', '508']
# ['491', '509']
# ['490', '510']
# ['489', '511']
# ['488', '512']
# ['487', '513']
# ['486', '514']
# ['485', '515']
# ['484', '516']
# ['483', '517']
# ['482', '518']
# ['481', '519']
# ['480', '520']
# ['479', '521']
# ['478', '522']
# ['477', '523']
# ['476', '524']
# ['475', '525']
# ['474', '526']
# ['473', '527']
# ['472', '528']
# ['471', '529']
# ['470', '530']
# ['469', '531']
# ['468', '532']
# ['467', '533']
# ['466', '534']
# ['465', '535']
# ['464', '536']
# ['463', '537']
# ['462', '538']
# ['461', '539']
# ['460', '540']
# ['459', '541']
# ['458', '542']
# ['457', '543']
# ['456', '544']
# ['455', '545']
# ['454', '546']
# ['453', '547']
# ['452', '548']
# ['451', '549']
# ['450', '550']
# ['449', '551']
# ['448', '552']
# ['447', '553']
# ['446', '554']
# ['445', '555']
# ['444', '556']
# ['443', '557']
# ['442', '558']
# ['441', '559']
# ['440', '560']
# ['439', '561']
# ['438', '562']
# ['437', '563']
# ['436', '564']
# ['435', '565']
# ['434', '566']
# ['433', '567']
# ['432', '568']
# ['431', '569']
# ['430', '570']
# ['429', '571']
# ['428', '572']
# ['427', '573']
# ['426', '574']
# ['425', '575']
# ['424', '576']
# ['423', '577']
# ['422', '578']
# ['421', '579']
# ['420', '580']
# ['419', '581']
# ['418', '582']
# ['417', '583']
# ['416', '584']
# ['415', '585']
# ['414', '586']
# ['413', '587']
# ['412', '588']
# ['411', '589']
# ['410', '590']
# ['409', '591']
# ['408', '592']
# ['407', '593']
# ['406', '594']
# ['405', '595']
# ['404', '596']
# ['403', '597']
# ['402', '598']
# ['401', '599']
# ['400', '600']
# ['399', '601']
# ['398', '602']
# ['397', '603']
# ['396', '604']
# ['395', '605']
# ['394', '606']
# ['393', '607']
# ['392', '608']
# ['391', '609']
# ['390', '610']
# ['389', '611']
# ['388', '612']
# ['387', '613']
# ['386', '614']
# ['385', '615']
# ['384', '616']
# ['383', '617']
# ['382', '618']
# ['381', '619']
# ['380', '620']
# ['379', '621']
# ['378', '622']
# ['377', '623']
# ['376', '624']
# ['375', '625']
# ['374', '626']
# ['373', '627']
# ['372', '628']
# ['371', '629']
# ['370', '630']
# ['369', '631']
# ['368', '632']
# ['367', '633']
# ['366', '634']
# ['365', '635']
# ['364', '636']
# ['363', '637']
# ['362', '638']
# ['361', '639']
# ['360', '640']
# ['359', '641']
# ['358', '642']
# ['357', '643']
# ['356', '644']
# ['355', '645']
# ['354', '646']
# ['353', '647']
# ['352', '648']
# ['351', '649']
# ['350', '650']
# ['349', '651']
# ['348', '652']
# ['347', '653']
# ['346', '654']
# ['345', '655']
# ['344', '656']
# ['343', '657']
# ['342', '658']
# ['341', '659']
# ['340', '660']
# ['339', '661']
# ['338', '662']
# ['337', '663']
# ['336', '664']
# ['335', '665']
# ['334', '666']
# ['333', '667']
# ['332', '668']
# ['331', '669']
# ['330', '670']
# ['329', '671']
# ['328', '672']
# ['327', '673']
# ['326', '674']
# ['325', '675']
# ['324', '676']
# ['323', '677']
# ['322', '678']
# ['321', '679']
# ['320', '680']
# ['319', '681']
# ['318', '682']
# ['317', '683']
# ['316', '684']
# ['315', '685']
# ['314', '686']
# ['313', '687']
# ['312', '688']
# ['311', '689']
# ['310', '690']
# ['309', '691']
# ['308', '692']
# ['307', '693']
# ['306', '694']
# ['305', '695']
# ['304', '696']
# ['303', '697']
# ['302', '698']
# ['301', '699']
# ['300', '700']
# ['299', '701']
# ['298', '702']
# ['297', '703']
# ['296', '704']
# ['295', '705']
# ['294', '706']
# ['293', '707']
# ['292', '708']
# ['291', '709']
# ['290', '710']
# ['289', '711']
# ['288', '712']
# ['287', '713']
# ['286', '714']
# ['285', '715']
# ['284', '716']
# ['283', '717']
# ['282', '718']
# ['281', '719']
# ['280', '720']
# ['279', '721']
# ['278', '722']
# ['277', '723']
# ['276', '724']
# ['275', '725']
# ['274', '726']
# ['273', '727']
# ['272', '728']
# ['271', '729']
# ['270', '730']
# ['269', '731']
# ['268', '732']
# ['267', '733']
# ['266', '734']
# ['265', '735']
# ['264', '736']
# ['263', '737']
# ['262', '738']
# ['261', '739']
# ['260', '740']
# ['259', '741']
# ['258', '742']
# ['257', '743']
# ['256', '744']
# ['255', '745']
# ['254', '746']
# ['253', '747']
# ['252', '748']
# ['251', '749']
# ['250', '750']
# ['249', '751']
# ['248', '752']
# ['247', '753']
# ['246', '754']
# ['245', '755']
# ['244', '756']
# ['243', '757']
# ['242', '758']
# ['241', '759']
# ['240', '760']
# ['239', '761']
# ['238', '762']
# ['237', '763']
# ['236', '764']
# ['235', '765']
# ['234', '766']
# ['233', '767']
# ['232', '768']
# ['231', '769']
# ['230', '770']
# ['229', '771']
# ['228', '772']
# ['227', '773']
# ['226', '774']
# ['225', '775']
# ['224', '776']
# ['223', '777']
# ['222', '778']
# ['221', '779']
# ['220', '780']
# ['219', '781']
# ['218', '782']
# ['217', '783']
# ['216', '784']
# ['215', '785']
# ['214', '786']
# ['213', '787']
# ['212', '788']
# ['211', '789']
# ['210', '790']
# ['209', '791']
# ['208', '792']
# ['207', '793']
# ['206', '794']
# ['205', '795']
# ['204', '796']
# ['203', '797']
# ['202', '798']
# ['201', '799']
# ['200', '800']
# ['199', '801']
# ['198', '802']
# ['197', '803']
# ['196', '804']
# ['195', '805']
# ['194', '806']
# ['193', '807']
# ['192', '808']
# ['191', '809']
# ['190', '810']
# ['189', '811']
# ['188', '812']
# ['187', '813']
# ['186', '814']
# ['185', '815']
# ['184', '816']
# ['183', '817']
# ['182', '818']
# ['181', '819']
# ['180', '820']
# ['179', '821']
# ['178', '822']
# ['177', '823']
# ['176', '824']
# ['175', '825']
# ['174', '826']
# ['173', '827']
# ['172', '828']
# ['171', '829']
# ['170', '830']
# ['169', '831']
# ['168', '832']
# ['167', '833']
# ['166', '834']
# ['165', '835']
# ['164', '836']
# ['163', '837']
# ['162', '838']
# ['161', '839']
# ['160', '840']
# ['159', '841']
# ['158', '842']
# ['157', '843']
# ['156', '844']
# ['155', '845']
# ['154', '846']
# ['153', '847']
# ['152', '848']
# ['151', '849']
# ['150', '850']
# ['149', '851']
# ['148', '852']
# ['147', '853']
# ['146', '854']
# ['145', '855']
# ['144', '856']
# ['143', '857']
# ['142', '858']
# ['141', '859']
# ['140', '860']
# ['139', '861']
# ['138', '862']
# ['137', '863']
# ['136', '864']
# ['135', '865']
# ['134', '866']
# ['133', '867']
# ['132', '868']
# ['131', '869']
# ['130', '870']
# ['129', '871']
# ['128', '872']
# ['127', '873']
# ['126', '874']
# ['125', '875']
# ['124', '876']
# ['123', '877']
# ['122', '878']
# ['121', '879']
# ['120', '880']
# ['119', '881']
# ['118', '882']
# ['117', '883']
# ['116', '884']
# ['115', '885']
# ['114', '886']
# ['113', '887']
# ['112', '888']
# ['111', '889']
# ['110', '890']
# ['109', '891']
# ['108', '892']
# ['107', '893']
# ['106', '894']
# ['105', '895']
# ['104', '896']
# ['103', '897']
# ['102', '898']
# ['101', '899']
# ['100', '900']
# ['99', '901']
# ['98', '902']
# ['97', '903']
# ['96', '904']
# ['95', '905']
# ['94', '906']
# ['93', '907']
# ['92', '908']
# ['91', '909']
# ['90', '910']
# ['89', '911']
# ['88', '912']
# ['87', '913']
# ['86', '914']
# ['85', '915']
# ['84', '916']
# ['83', '917']
# ['82', '918']
# ['81', '919']
# ['80', '920']
# ['79', '921']
# ['78', '922']
# ['77', '923']
# ['76', '924']
# ['75', '925']
# ['74', '926']
# ['73', '927']
# ['72', '928']
# ['71', '929']
# ['70', '930']
# ['69', '931']
# ['68', '932']
# ['67', '933']
# ['66', '934']
# ['65', '935']
# ['64', '936']
# ['63', '937']
# ['62', '938']
# ['61', '939']
# ['60', '940']
# ['59', '941']
# ['58', '942']
# ['57', '943']
# ['56', '944']
# ['55', '945']
# ['54', '946']
# ['53', '947']
# ['52', '948']
# ['51', '949']
# ['50', '950']
# ['49', '951']
# ['48', '952']
# ['47', '953']
# ['46', '954']
# ['45', '955']
# ['44', '956']
# ['43', '957']
# ['42', '958']
# ['41', '959']
# ['40', '960']
# ['39', '961']
# ['38', '962']
# ['37', '963']
# ['36', '964']
# ['35', '965']
# ['34', '966']
# ['33', '967']
# ['32', '968']
# ['31', '969']
# ['30', '970']
# ['29', '971']
# ['28', '972']
# ['27', '973']
# ['26', '974']
# ['25', '975']
# ['24', '976']
# ['23', '977']
# ['22', '978']
# ['21', '979']
# ['20', '980']
# ['19', '981']
# ['18', '982']
# ['17', '983']
# ['16', '984']
# ['15', '985']
# ['14', '986']
# ['13', '987']
# ['12', '988']
# ['11', '989']
# ['10', '990']
# ['9', '991']
# ['8', '992']
# ['7', '993']
# ['6', '994']
# ['5', '995']
# ['4', '996']
# ['3', '997']
# ['2', '998']
# ['1', '999']
# ['0', '1000']

# %% [markdown]
# What does this little piece of code do?
#
#
# *Note to Windows users*: to open a file for reading and writing in binary mode, set the access mode to 'wb+'.

# %% [markdown]
# ### Trying to read and write in the same loop? No problem.
#
# Below is a template of what this process might look like:
# ```
# with open(newfile, 'wb') as outfile, open(oldfile, 'rb') as infile:
#     for name in infile:
#         if name.startswith('C') or name.startswith('G'):
#             line = name + ' - Truly a great person!\n'
#         outfile.write(line)
# ```

# %% [markdown]
# ## 4. User input
#
# Let's stay your Python script needs some user input to proceed. How can we capture keyboard input in Python?
#
# Note: There's a difference between how this works in Python 2.7 and 3.0 (https://docs.python.org/3/whatsnew/3.0.html). Be sure to use the method that corresponds to your version of Python :)

# %%
s = raw_input('--> ')
print s
# Out:
# --> Hello World
# Hello World

# %%
print 'You entered: ' + s  # anything you enter will be considered a string
# Out:
# You entered: Hello World

# %% [markdown]
# #### A note about Python 3
#
# To capture user input in Python 3.0, this is what you'd do:
#
#     s = input()
#
# This will throw an error in Python 2.7.

# %% [markdown]
# ## 5. Pandas
#
# Pandas is a library that's useful for analyzing medium-sized (hundreds of thousands of rows) datasets. Its primary data abstraction is a "data frame" that is very similar to the R DataFrame. Check out the tutorials here: http://pandas.pydata.org/pandas-docs/version/0.15.2/tutorials.html.  If you are interested in learning more about pandas, also check out the notebook python_6_final_project_with_pandas.ipynb.
